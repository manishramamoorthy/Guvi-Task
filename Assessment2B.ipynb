# %% [markdown]
# <a href="https://colab.research.google.com/github/manishramamoorthy/manishramamoorthy/blob/main/Assessment2B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
df1=pd.read_csv("/content/college_1 (1).csv")
df2=pd.read_csv("/content/college_2 (1).csv")

# %%
df1
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 79    KarthikeyanS    45.0    0.0                  0               0
# 80        BARATH.P    29.0    0.0                  0               0
# 81   N.Ajith kumar    82.0    0.0                  0               0
# 82    mohamed nabi     0.0    0.0                  0               0
# 83  yaser ahamed.A     0.0   27.0                  0               0
#
#                                 Department  Rising
# 0         Computer Science and Engineering       0
# ...

# %%
df1.shape
# Out:
# (84, 7)

# %%
df2
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 0            ASHOK KUMAR K     100          0     31                       9
# 1                  Chandru       0         20      0                       0
# 2        Ganesh Ramkumar R      -1         55     24                       6
# 3          Bodipudi Harini      -1          0     35                      -1
# 4                VIINU V P      -1        100     24                      -1
# 5               Poojitha Y       0         78     35                       0
# 6   Gowtham Chandrasekaran      -1          0      0                       3
# 7                Gowtham R      -1         60      4                       6
# 8                 shifak N      58          0      0                       0
# 9                  Balaji       -1        100     20                       0
# 10                Rushitha      -1         15     62                       9
# ...

# %%
df2.shape
# Out:
# (35, 9)

# %%
df=df1.append(df2,ignore_index = True)
df
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 114  praveen raj j    24.0    0.0               2380            2380
# 115     AMARNATH D    -1.0   12.0               1890            1890
# 116           bala    32.0    0.0               1720            1720
# 117           XY Z    -1.0   -1.0                  0               0
# 118      Hariharan    -1.0   -1.0                  0               0
#
#                                     Department  Rising  python_en  \
# 0             Computer Science and Engineering       0        NaN
# ...

# %%
df.shape
# Out:
# (119, 9)

# %%
final_df=df.fillna(0)
final_df
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 114  praveen raj j    24.0    0.0               2380            2380
# 115     AMARNATH D    -1.0   12.0               1890            1890
# 116           bala    32.0    0.0               1720            1720
# 117           XY Z    -1.0   -1.0                  0               0
# 118      Hariharan    -1.0   -1.0                  0               0
#
#                                     Department  Rising  python_en  \
# 0             Computer Science and Engineering       0        0.0
# ...

# %%
final_df
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 114  praveen raj j    24.0    0.0               2380            2380
# 115     AMARNATH D    -1.0   12.0               1890            1890
# 116           bala    32.0    0.0               1720            1720
# 117           XY Z    -1.0   -1.0                  0               0
# 118      Hariharan    -1.0   -1.0                  0               0
#
#                                     Department  Rising  python_en  \
# 0             Computer Science and Engineering       0        0.0
# ...

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
exceed_expectations=final_df[final_df["CodeKata Score"]>15000]
exceed_expectations.to_csv("exceed_expectations.csv")

# %%
reached_expectations=final_df[(final_df["CodeKata Score"]>10000) & (final_df["CodeKata Score"]<15000)]
reached_expectations.to_csv("reached_expectations.csv")

# %%
needs_improvement=final_df[(final_df["CodeKata Score"]>7000) & (final_df["CodeKata Score"]<10000)]
needs_improvement.to_csv("needs_improvement.csv")

# %%
unsatisfactory=final_df[final_df["CodeKata Score"]<7000]
unsatisfactory.to_csv("unsatisfactory.csv")

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
df1.columns
# Out:
# Index(['Name', 'python', 'mysql', 'Previous Geekions', 'CodeKata Score',
#        'Department', 'Rising'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['Name', 'python', 'python_en', 'mysql', 'computational_thinking',
#        'Previous Geekions', 'CodeKata Score', 'Department', 'Rising'],
#       dtype='object')

# %%
col=["Previous Geekions" , "CodeKata Score"]
final_df[col].mean()
# Out:
# Previous Geekions    3842.352941
# CodeKata Score       4051.764706
# dtype: float64

# %% [markdown]
# ###### No of students participated

# %%
df.shape
# Out:
# (119, 9)

# %%
stu=final_df.shape[0]
print("No of students participated",stu)
# Out:
# No of students participated 119

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
python_completion=final_df[final_df["python"]==100]
python_completion
# Out:
#                           Name  python   mysql  Previous Geekions  \
# 2                  HEMAVATHI.R   100.0  100.00              19680
# 3                  Mugunthan S   100.0   47.00              10610
# 4                  Sathammai.S   100.0    8.00               8980
# 5                 NIVEESHWAR S   100.0    0.00               8200
# 11                Ponniyamma.R   100.0   11.25               5380
# 12                   SABAPATHI   100.0    0.00               5280
# 13                    RAGHAVAN   100.0    0.00               5120
# 15                    Pavithra   100.0  100.00               4600
# 17                 v.vithyasri   100.0   12.00               4370
# 18          Abirami Anbazhagan   100.0    0.00               4320
# 19                S.srinivasan   100.0   12.00               4090
# 20                    s.janani   100.0    0.00               3915
# 22                     Yuvasri   100.0  100.00               3460
# ...

# %%
python_completion.shape
# Out:
# (41, 9)

# %%
print("number of student completion in python course: ",python_completion.shape[0])
print("total number of students: ",final_df.shape[0])
result=(python_completion.shape[0]/final_df.shape[0])*100
print("Average of student in completed in python assesment:",round(result))
# Out:
# number of student completion in python course:  41
# total number of students:  119
# Average of student in completed in python assesment: 34

# %%
mysql_completion=final_df[final_df["mysql"]==100]
mysql_completion
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 15       Pavithra   100.0  100.0               4600            4600
# 22        Yuvasri   100.0  100.0               3460            3460
# 24        MEERA.M   100.0  100.0               3200            3200
# 26  sri dharshini   100.0  100.0               3110            3110
# 28  pooja priya.B   100.0  100.0               2570            2570
# 34     tamilarasi   100.0  100.0               1910            1910
# 44        ponni.p    93.0  100.0               1350            1350
# 45     PRAVEENA K   100.0  100.0               1320            1320
# 49       bavithra     0.0  100.0               1020            1020
# 56        pravina   100.0  100.0                720             720
# 64     k.parvathi   100.0  100.0                260             260
# 77     J.JAYANTHI   100.0  100.0                 40              40
# ...

# %%
mysql_completion.shape
# Out:
# (14, 9)

# %%
print("number of student in completion in mysql course: ",mysql_completion.shape[0])
print("total number of student: ",final_df.shape[0])
result=(mysql_completion.shape[0]/final_df.shape[0])*100
print("Average of student completion in mysql: ",round(result))
# Out:
# number of student in completion in mysql course:  14
# total number of student:  119
# Average of student completion in mysql:  12

# %%
pythonenglish_completion=final_df[final_df["python_en"]==100]
pythonenglish_completion
# Out:
#          Name  python  mysql  Previous Geekions  CodeKata Score  \
# 88  VIINU V P    -1.0   24.0               9150            9150
# 93    Balaji     -1.0   20.0               6170            8160
#
#                                 Department  Rising  python_en  \
# 88  Electronics and Electrical Engineering       0      100.0
# 93  Electronics and Electrical Engineering    1990      100.0
#
#     computational_thinking
# 88                    -1.0
# 93                     0.0

# %%
pythonenglish_completion.shape
# Out:
# (2, 9)

# %%
print("number of student completion in python english: ",pythonenglish_completion.shape[0])
print("total number of students: ",final_df.shape[0])
result=(pythonenglish_completion.shape[0]/final_df.shape[0])*100
print("Average of student in completion in python english:",round(result))
# Out:
# number of student completion in python english:  2
# total number of students:  119
# Average of student in completion in python english: 2

# %%
computationalthinking_completion=final_df[final_df["computational_thinking"]==100]
computationalthinking_completion
# Out:
# Empty DataFrame
# Columns: [Name, python, mysql, Previous Geekions, CodeKata Score, Department, Rising, python_en, computational_thinking, performed]
# Index: []

# %%
computationalthinking_completion.shape
# Out:
# (0, 9)

# %%
print("number of student completion in computational thinking: ",computationalthinking_completion.shape[0])
print("total number of students: ",final_df.shape[0])
result=(computationalthinking_completion.shape[0]/final_df.shape[0])*100
print("Average of student in completion in computational thinking: ",round(result))
# Out:
# number of student completion in computational thinking:  0
# total number of students:  119
# Average of student in completion in computational thinking:  0

# %%
average=final_df.loc[(final_df["python"]==100) | (final_df["mysql"]==100) | (final_df["python_en"]==100) | (final_df["computational_thinking"]==100)]
average.shape
# Out:
# (46, 10)

# %%
result=(average.shape[0]/final_df.shape[0])*100
print("Average completion of python course or my_sql or python english or computational thinking: ",round(result))
# Out:
# Average completion of python course or my_sql or python english or computational thinking:  39

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
final_df["performed"]=final_df['CodeKata Score'] - final_df["Previous Geekions"]
final_df
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 114  praveen raj j    24.0    0.0               2380            2380
# 115     AMARNATH D    -1.0   12.0               1890            1890
# 116           bala    32.0    0.0               1720            1720
# 117           XY Z    -1.0   -1.0                  0               0
# 118      Hariharan    -1.0   -1.0                  0               0
#
#                                     Department  Rising  python_en  \
# 0             Computer Science and Engineering       0        0.0
# ...

# %%
rising_star=final_df.nlargest(3,["performed"])
rising_star
# Out:
#                   Name  python  mysql  Previous Geekions  CodeKata Score  \
# 92            shifak N    58.0    0.0               5180            8320
# 86   Ganesh Ramkumar R    -1.0   24.0               8790           10790
# 102     Narasimhan Y L    -1.0    0.0               4800            6800
#
#                                  Department  Rising  python_en  \
# 92   Electronics and Electrical Engineering    3140        0.0
# 86         Computer Science and Engineering    2000       55.0
# 102        Computer Science and Engineering    2000       -1.0
#
#      computational_thinking  performed
# 92                      0.0       3140
# 86                      6.0       2000
# 102                     0.0       2000

# %%
print("rising star of the week (top 3 candidate who performed well in that particular week) are,")
for i in rising_star["Name"]:
  print(i)
# Out:
# rising star of the week (top 3 candidate who performed well in that particular week) are,
# shifak N
# Ganesh Ramkumar R
# Narasimhan Y L

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
shining_stars=final_df.nlargest(3,["CodeKata Score"])
shining_stars
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  \
# 0  Computer Science and Engineering       0        0.0
# 1  Computer Science and Engineering       0        0.0
# 2  Computer Science and Engineering       0        0.0
#
#    computational_thinking  performed
# 0                     0.0          0
# 1                     0.0          0
# 2                     0.0          0

# %%
print("Shining stars of the week (top 3 candidates who has highest geekions) are,")
for i in shining_stars["Name"]:
  print(i)
# Out:
# Shining stars of the week (top 3 candidates who has highest geekions) are,
# A.Dharani
# V.JEEVITHA
# HEMAVATHI.R

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
final_df["Department"].unique()
# Out:
# array(['Computer Science and Engineering',
#        'Electronics and Communication Engineering',
#        'Electronics and Electrical Engineering'], dtype=object)

# %%
com_sci=final_df[final_df["Department"]=="Computer Science and Engineering"]
com_sci

# %%
com_sci['CodeKata Score'].mean()
# Out:
# 5079.761904761905

# %%
ECE=final_df[final_df["Department"]=="Electronics and Communication Engineering"]
ECE

# %%
ECE["CodeKata Score"].mean()
# Out:
# 2777.8205128205127

# %%
EEE=final_df[final_df["Department"]=="Electronics and Electrical Engineering"]
EEE

# %%
EEE["CodeKata Score"].mean()
# Out:
# 3164.705882352941

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
pie_chart=np.array([5079.761904761905,2777.8205128205127,3164.705882352941])
mylabels=["Computer Science and Engineering","Electronics and Communication Engineering","Electronics and Electrical Engineering"]

plt.pie(pie_chart,labels=mylabels,startangle=90,autopct="%1.1f%%",radius=1.5)
plt.title("Department wise codekata performence")
plt.show()

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
CS_toppers=com_sci.nlargest(5,["CodeKata Score"])
CS_toppers
# Out:
#                  Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0           A.Dharani    82.0   20.0              24500           24500
# 1         V.JEEVITHA     82.0   20.0              21740           21740
# 2         HEMAVATHI.R   100.0  100.0              19680           19680
# 85            Chandru     0.0    0.0              14150           14490
# 86  Ganesh Ramkumar R    -1.0   24.0               8790           10790
#
#                           Department  Rising  python_en  \
# 0   Computer Science and Engineering       0        0.0
# 1   Computer Science and Engineering       0        0.0
# 2   Computer Science and Engineering       0        0.0
# 85  Computer Science and Engineering     340       20.0
# 86  Computer Science and Engineering    2000       55.0
#
#     computational_thinking  performed
# 0                      0.0          0
# 1                      0.0          0
# 2                      0.0          0
# ...

# %%
plt.bar(CS_toppers["Name"],CS_toppers["CodeKata Score"])
plt.title("Computer Science and Engineering")
plt.xlabel("Name")
plt.ylabel("CodeKata Score")
plt.show()

# %%
ECE_toppers=ECE.nlargest(5,["CodeKata Score"])
ECE_toppers
# Out:
#                 Name  python  mysql  Previous Geekions  CodeKata Score  \
# 87   Bodipudi Harini    -1.0   35.0              10040           10040
# 91         Gowtham R    -1.0    4.0               8650            8650
# 6      KALAIARASAN K    85.0   47.0               7750            7880
# 98         Praneetha    -1.0  100.0               7170            7730
# 100          Guhan S    -1.0   35.0               7310            7630
#
#                                     Department  Rising  python_en  \
# 87   Electronics and Communication Engineering       0        0.0
# 91   Electronics and Communication Engineering       0       60.0
# 6    Electronics and Communication Engineering     130        0.0
# 98   Electronics and Communication Engineering     560       23.0
# 100  Electronics and Communication Engineering     320       72.0
#
#      computational_thinking  performed
# 87                     -1.0          0
# 91                      6.0          0
# ...

# %%
plt.bar(ECE_toppers["Name"],ECE_toppers["CodeKata Score"])
plt.title("Electronics and Communication Engineering")
plt.xlabel("Name")
plt.ylabel("CodeKata Score")
plt.show()

# %%
EEE_toppers=EEE.nlargest(5,["CodeKata Score"])
EEE_toppers
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 84  ASHOK KUMAR K   100.0   31.0              19400           19400
# 88      VIINU V P    -1.0   24.0               9150            9150
# 92       shifak N    58.0    0.0               5180            8320
# 93        Balaji     -1.0   20.0               6170            8160
# 96       JPradhap   100.0    0.0               7340            8030
#
#                                 Department  Rising  python_en  \
# 84  Electronics and Electrical Engineering       0        0.0
# 88  Electronics and Electrical Engineering       0      100.0
# 92  Electronics and Electrical Engineering    3140        0.0
# 93  Electronics and Electrical Engineering    1990      100.0
# 96  Electronics and Electrical Engineering     690        0.0
#
#     computational_thinking  performed
# 84                     9.0          0
# 88                    -1.0          0
# 92                     0.0       3140
# ...

# %%
plt.bar(EEE_toppers["Name"],EEE_toppers["CodeKata Score"])
plt.title("Electronics and Electrical Engineering")
plt.xlabel("Name")
plt.ylabel("CodeKata Score")
plt.show()
